# %%
from pycaret.classification import *
from pycaret.datasets import get_data

# %% [markdown]
# ### Dataset

# %%
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### 초기 설정

# %%
s = setup(
    data = data, target='species',
    session_id=123,              # 랜덤 시드 (해당 ID를 통해 결과 재현 가능)
    normalize=False,             # 데이터 정규화 유무
    # normalize_method='minmax', # 데이터 정규화 방법 (zscore, minmax, maxabs, robust)
    transformation=False,        # Power Transformation 유무
    fold=10,                     # Cross-Validation fold 수
    use_gpu=False                # GPU 사용 유무
)
# Out:
# <style type="text/css">
# #T_c74ef_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c74ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c74ef_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c74ef_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c74ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c74ef_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c74ef_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c74ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c74ef_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c74ef_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_c74ef_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# ### Model 학습

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:38:44
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_155ca th {
#   text-align: left;
# }
# ...

# %%
lr = create_model('lr')
tuned_model = tune_model(lr, n_iter=10, optimize='Accuracy')
# Out:
# <style type="text/css">
# #T_f6635_row10_col0, #T_f6635_row10_col1, #T_f6635_row10_col2, #T_f6635_row10_col3, #T_f6635_row10_col4, #T_f6635_row10_col5, #T_f6635_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f6635">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6635_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f6635_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f6635_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f6635_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f6635_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f6635_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f6635_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# ### Model 시각화

# %%
plot_model(best, plot = 'confusion_matrix')
plot_model(best, plot = 'auc')
plot_model(best, plot = 'feature')

# %% [markdown]
# ### Prediction

# %%
holdout_pred = predict_model(best)
holdout_pred.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a626">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a626_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5a626_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5a626_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5a626_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5a626_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5a626_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5a626_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5a626_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a626_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a626_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %% [markdown]
# ### Model Save & Load

# %%
save_model(best, 'iris_pipeline')

loaded_best_pipeline = load_model('iris_pipeline')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\BMILab\AppData\Local\Temp\joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['sepal_length', 'sepal_width',
#                                              'petal_length', 'petal_width'],
#                                     transformer=SimpleImputer(add_indicator=...
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
# ...
